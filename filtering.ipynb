# %%
import cv2
import matplotlib.pyplot as plt
import filters

# %%
path_to_image = './images/image.png'
filtered_image = filters.median_filter(path_to_image, 35)

# %%
plt.imshow(cv2.cvtColor(filtered_image, cv2.COLOR_BGR2RGB)) 
plt.show()

# %%
# сохранить изображение
cv2.imwrite("./output/median_fileter.jpg", filtered_image)
# Out:
# True
